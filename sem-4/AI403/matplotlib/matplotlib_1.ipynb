# %% [markdown]
# # Data visualization
# - It simplified data understanding
# - It reveals relationship
# - support decision making
# - commmunicate results eeffectivly
# - detect anomolies(outliers, errors or unusual pattern)
#
# ## Popular and widly used visualization libraries
# - plotly
# - ggplot
# - pandas ploting
# - panel, etc
#
# ## Matplotlib
# It is used for creating 2d plots and charts. It convert numerical data into visual form, such as line graph, bar chart, histogram, scatter plot, pie chart, etc.. It uses module called pyplot, which provide functions to the matplotlib.
#
# ### Other modules in matplotlib
# - figure
# - axes
# - ticker
# - style
# - animation, etc
#
# ### pyplot
# It is a sub module of matplotlib that provides a simple and easy to use interface for creating graphs and plots in python
#
# #### How to import pyplot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### basic flow of pyplot
# 1. prepare data
# 2. call plotting function
# 3. customize graph
# 4. display the graph
#
# #### Line Plot/Line Graph
# it shows trends over a continuous variable
#
# ##### It is of two types *single line* and *multi line*
# 1. single line plot one series of data points, connected my lines
# 2. multi lines compare two of more dataset on the same axis

# %%
x = [i for i in range(1, 6)]
y = [i for i in range(10, 51, 10)]

plt.plot(x, y)

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line plot")

plt.show()

# %% [markdown]
# ##### customization
# - colors
# - linestyle
# - markers

# %%
plt.plot(x, y, color="red", marker="o", linestyle="--")
plt.show()

# %%
#multi-line graph

x = [i for i in range(1, 6)]
y1 = [i for i in range(10, 51, 10)]
y2 = [9, 25, 36, 90, 99]

plt.plot(x, y1, color="blue", marker="o", linestyle="--")
plt.plot(x, y2, color="green", marker="x")

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("A graph")

plt.show()

# %% [markdown]
# ##### Legends and grids
#
# - Legends
#
# label agrument in plt.plot()
# `plt.plot(x, y, label="<label>")`
# `plt.legend()`
#
# - Grid
# `plt.grid(True)`

# %%
#multi-line graph

x = [i for i in range(1, 6)]
y1 = [i for i in range(10, 51, 10)]
y2 = [9, 25, 36, 90, 99]

plt.plot(x, y1, color="blue", marker="x", linestyle=":", label="IOT")
plt.plot(x, y2, color="green", marker="o", label="AIML")

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("A graph")
plt.legend()
plt.grid(True)

plt.show()

# %%
#list in x axis, array in y axis

import numpy as np

x = [1, 2, 3, 4, 5]
y = np.array([10, 30, 40, 60, 90])

plt.plot(x, y)
plt.show()

# %%
# use 2 parameter markersize and linewidth

x = [1, 2, 3, 4, 5]
y = [10, 30, 40, 60, 90]

plt.plot(x, y, marker="x", markersize="50", linewidth="2")
plt.show()

# %%
#Q1. from classroom on 28jan2026

x = ["Mon", "Tues", "Wed", "Thrs", "Fri"]
y = [22, 24, 23, 25, 26]

plt.plot(x, y, marker="H")

plt.title("Temperature")
plt.xlabel("day")
plt.ylabel("temp in C")
plt.grid()

plt.show()

# %%
#Q2. from classroom on 28jan2026

x = ["Mon", "Tues", "Wed", "Thrs", "Fri"]
desktop_user = [1200, 1350, 1500, 1600, 1800]
mobile_user = [1800, 2000, 2300, 2500, 2800]

plt.plot(x, desktop_user, color="c", marker="*", linestyle="-.", linewidth="2", markersize="10", label="Desktop Users")
plt.plot(x, mobile_user, color="m", marker="|", linestyle=":", linewidth="3", markersize="10", label="Mobile Users")

plt.xlabel("Days")
plt.ylabel("no. of users")
plt.legend()
plt.title("Website traffic analysis")
plt.grid()

plt.show()

# %% [markdown]
# 1. Which device (desktop or mobile) has higher website traffic throughout the week?
# Mobile
#
# 2. On which day is the total number of visitors the highest?
# Friday
#
# 3.  Which device shows a faster growth rate over the five days?
# Mobile
#
# 4.  Between which two consecutive days is the highest increase in mobile users observed?
# Tuesday & Thrusday
#
# 5.  Is the gap between desktop and mobile users increasing or decreasing over time?
# Increasing
#
# 6.  What trend do you observe in desktop user traffic during the week?
# Low traffic, slight increase
#
# 7.  What can you conclude about user preference for devices based on the graph?
# User prefers mobile
#
# 8.  If this trend continues, which device is likely to dominate website traffic in the future? Why?
# Mobile
#
# 9.  What business decision can be taken based on the observed traffic pattern?
#
#
# 10.Suggest one improvement the website team should focus on, based on the graph.
#
#
# 11.Why is it important for the website to be mobile-friendly, according to the data shown?
# Because majority of users are accessing the site from mobile.

# %% [markdown]
# #### Bar Plot
# It is a graphical representation of data using rectangular bars, where the length and height of each bar is proposnal to the value it represent. <br>
# It is mainly used for comparing quantity across different categories.
#
# ##### Types of Bar Plot
# 1. Vertical Bar Plot
# 2. Horizontal Bar Plot
# 3. Multiple Bar Chart
#
# ##### syntax
# `plt.bar(x, height)`
#
# ###### 1. Vertical Bar Plot

# %%
#Q. prepare a bar chart to show marks scored by a student in 5 subjects

x = ["English", "Maths", "Science", "CS"]
h = [80, 20, 40, 90]

plt.bar(x, h, width=0.1, label="Student A", color=['b', 'c', 'm', 'y'])

plt.xlabel("subjects")
plt.ylabel("marks")
plt.legend()


plt.show()

# %% [markdown]
# ###### 2. Horizontal Bar

# %%
# horizontal Bar

x = ["English", "Maths", "Science", "CS"]
h = [80, 20, 40, 90]

plt.barh(x, h, height=0.2, label="Student A", color=['b', 'c', 'm', 'y'])

plt.ylabel("subjects")
plt.xlabel("marks")
plt.legend()


plt.show()

# %% [markdown]
# ##### Labelling each bar

# %%
x = ["English", "Maths", "Science", "CS"]
h = [80, 20, 40, 90]

bar_width = 0.9

plt.bar(x, h, width=bar_width, label="Student A", color=['b', 'c', 'm', 'y'])

for i in range(len(x)):
    plt.text(i - (bar_width//2), h[i] + 1, h[i])

plt.xlabel("subjects")
plt.ylabel("marks")
plt.legend()


plt.show()

# %%
#Q from classroom 28jan2026

x = ['sub1', 'sub2', 'sub3', 'sub4', 'sub5']

stu1 = [78, 85, 74, 80, 90]
stu2 = [70, 88, 76, 82, 85]

plt.bar(x, stu1, color='c')
plt.bar(x, stu2, color='m', alpha=0.5)

plt.show()
